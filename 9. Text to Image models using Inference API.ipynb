# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhangkhare/Transformers/blob/main/9.%20Text%20to%20Image%20models%20using%20Inference%20API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hugging Face Models

# %%
import requests

#API_URL = "https://api-inference.huggingface.co/models/stabilityai/stable-diffusion-xl-base-1.0"
#API_URL =  "https://api-inference.huggingface.co/models/runwayml/stable-diffusion-v1-5"
#API_URL = "https://api-inference.huggingface.co/models/Joeythemonster/anything-midjourney-v-4-1"
API_URL = "https://api-inference.huggingface.co/models/CompVis/stable-diffusion-v1-4"


headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.content
image_bytes = query({
	"inputs": "A 3D render of a hand swiping rectangular card in geometric village, futuristic, orange background",
})
# You can access the image with PIL.Image for example
import io
from PIL import Image
image = Image.open(io.BytesIO(image_bytes))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# # Imagine AI

# %% [markdown]
# ## Text to Image

# %%
import requests
from IPython.display import Image
from PIL import Image

def generate_image(prompt, num_images):
    url = 'https://api.vyro.ai/v1/imagine/api/generations'

    headers = {
            'bearer': 'vk-GR1I1WnB8AoeD5Eqv6nFSleFPRl5JRRgx26CFpeLAEo%3D'
    }
    # Using None here allows us to treat the parameters as string
    data = {
        'model_version': (None, '1'), # Model Version
        'prompt': (None, prompt),
        'style_id': (None, '30'), # Specify Random Seed
    }
    results = []
    for num_image in range(num_images):
        response = requests.post(url, headers=headers, files=data)
        if response.status_code == 200:  # if request is successful
            with Image.open(io.BytesIO(response.content)) as img:
                #results.append(response.content)
                display(img)
        else:
            print("Error:", response.status_code)

# %%
generate_image('A 3D render of a hand swiping rectangular card in geometric village, futuristic, orange background', 1)
# Out:
# <Response [402]>
# Error: 402
